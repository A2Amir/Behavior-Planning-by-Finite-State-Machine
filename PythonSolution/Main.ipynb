# %%
import simulate_behavior

# %%
simulate_behavior.run_simulation(VISUALIZE=True)
# Out:
# 000 - |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     | *** |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     | 014 |
#       |     |     |     |     |
#       |     | 006 |     | 015 |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     | 010 |     |
#       | 001 | 007 |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       |     |     |     |     |
# 020 - |     |     |     | 016 |
#       |     |     |     |     |
#       | 002 |     |     |     |
#       |     |     | 011 |     |
#       |     |     |     |     |
#       |     |     |     |     |
#       | 003 |     |     |     |
#       |     |     |     | 017 |
#       |     |     |     |     |
# ...
